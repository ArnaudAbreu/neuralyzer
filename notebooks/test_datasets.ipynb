# %%
from neuralyzer.datasets import FlatGrayPatchDataset

# %%
dataset = FlatGrayPatchDataset(patch_size=16, stride=1, batch_size=32)

# %%
loader = dataset.load("/Users/arnaudabreu/Downloads/lenna.png")

# %%
for elem in loader:
    img = elem["image"]
    position = elem["position"]
    y, x = position
    print(img.shape)
    print(f"y: {len(y)} x: {len(x)}")
    break
# Out:
# torch.Size([32, 256])
# y: 32 x: 32

# %%
for elem in loader:
    img = elem["image"]
    print(img.shape)
# Out:
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# torch.Size([32, 256])
# ...
